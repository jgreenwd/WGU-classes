# %% [markdown]
# # Capstone Project Notebook: TLaP - Throw Like a Pro
# ## Baseball Pitch Multi-Classification Using Expectation Maximization and Multi-Layer Perceptron
#
# Jeremy Greenwood
#
# C964 - Computer Science Capstone<br>
# Western Governors University<br>
# August 2020

# %% [markdown]
# #### Environment Initialization

# %%
## Gain access to utility / display functions & necessary classes
# %run './utils.py'
# %run './Dashboard.py'
# %run './Pitch.py'
# %run './Pitcher.py'

## Create local reference to external data set
df_full = pd.read_csv(f'./capstone-data/pitches.csv')

#### only used in development
# %run './unittests.py'
# unittest.main(argv=[''], verbosity=2, exit=False)

# training_data = df_full[df_full.ab_id.between(2015000000, 2017000000)]
# tuning_data = df_full[df_full.ab_id.between(2017000000, 2018000000)]
# testing_data = df_full[df_full.ab_id.between(2018000000, 2019000000)]

## Render matplotlib plots in the notebook
# %matplotlib inline

# %% [markdown]
# #### User Dashboard

# %%
dbd = Dashboard(df_full, PLAYERS)
dbd.render_dashboard()
